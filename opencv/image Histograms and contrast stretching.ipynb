# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import os
os.chdir('../data')

# %%
# img = np.zeros((500, 500), np.uint8)
# cv.rectangle(img, (0, 255), (500, 500), (255), -1)
# cv.rectangle(img, (0, 125), (250, 250), (127), -1)
# plt.hist(img.ravel(), 255, [0, 255])

img = cv.imread('lenna.png')
b, g, r = cv.split(img)


plt.hist(img.ravel(), 255, [0, 255])
plt.hist(b.ravel(), 255, [0, 255])
plt.hist(g.ravel(), 255, [0, 255])
plt.hist(r.ravel(), 255, [0, 255])


plt.show()

cv.imshow('b', b)
cv.imshow('g', g)
cv.imshow('r', r)
cv.imshow('img', img)
cv.waitKey()
cv.destroyAllWindows()

# %% [markdown]
# ### use calcHist

# %%
img = cv.imread('lenna.png', 0)
#                    chanel  mask
hist = cv.calcHist(img, [0], None, [255], [0, 255])
plt.plot(hist)
plt.show()

# %%
import cv2 as cv

# %%
cap = cv.VideoCapture(0, cv.CAP_OPENNI_DEPTH_MAP)

while cap.isOpened():
    ret, frame = cap.read()

    cv.imshow('frame', frame)
    if cv.waitKey(30) == 27:
        break
cap.release()
cv.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x55be6bfc44e0) is not the object's thread (0x55be6c4cee70).
# Cannot move to target thread (0x55be6bfc44e0)
#
# QObject::moveToThread: Current thread (0x55be6bfc44e0) is not the object's thread (0x55be6c4cee70).
# Cannot move to target thread (0x55be6bfc44e0)
#
# QObject::moveToThread: Current thread (0x55be6bfc44e0) is not the object's thread (0x55be6c4cee70).
# Cannot move to target thread (0x55be6bfc44e0)
#
# QObject::moveToThread: Current thread (0x55be6bfc44e0) is not the object's thread (0x55be6c4cee70).
# Cannot move to target thread (0x55be6bfc44e0)
#
# QObject::moveToThread: Current thread (0x55be6bfc44e0) is not the object's thread (0x55be6c4cee70).
# Cannot move to target thread (0x55be6bfc44e0)
#
# QObject::moveToThread: Current thread (0x55be6bfc44e0) is not the object's thread (0x55be6c4cee70).
# Cannot move to target thread (0x55be6bfc44e0)
#
# ...
